# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('old_gridtest_output.txt')
df_nona = df.dropna()

# %%
plt.hist(df_nona['distance'], bins = 20, range = [0,100]);
ticks,labels = plt.xticks()

# %%
df_nona['distance'].max()
# Out:
# 3.500000011941228
